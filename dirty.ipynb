# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('dirty_housing_data.csv')

# %%
df.shape
# Out:
# (205, 6)

# %%
df.Age_of_house_yrs
# Out:
# 0       NaN
# 1       0.0
# 2       NaN
# 3      30.0
# 4       0.0
#        ...
# 200    30.0
# 201     2.0
# 202     0.0
# 203    15.0
# 204     5.0
# Name: Age_of_house_yrs, Length: 205, dtype: float64

# %%
df.describe()
# Out:
#        Age_of_house_yrs          Price
# count        184.000000     195.000000
# mean           9.679348  399166.825641
# std            9.745415  214702.705077
# min            0.000000   50126.000000
# 25%            1.000000  213030.000000
# 50%           10.000000  377073.000000
# 75%           15.000000  592520.500000
# max           30.000000  791804.000000

# %%
df.isnull()
# Out:
#      Area_sqft  Bedrooms  Distance_to_city_km  Age_of_house_yrs  Has_Garage  \
# 0        False     False                False              True       False
# 1        False     False                False             False       False
# 2        False     False                False              True       False
# 3        False     False                False             False       False
# 4        False     False                False             False       False
# ..         ...       ...                  ...               ...         ...
# 200      False     False                False             False       False
# 201      False     False                False             False       False
# 202      False     False                False             False       False
# 203      False     False                False             False       False
# 204      False     False                False             False       False
#
#      Price
# 0    False
# 1    False
# 2    False
# ...

# %%
df.isnull().sum()
# Out:
# Area_sqft               0
# Bedrooms               20
# Distance_to_city_km     1
# Age_of_house_yrs       21
# Has_Garage              0
# Price                  10
# dtype: int64

# %%
df.Bedrooms
# Out:
# 0          4
# 1          4
# 2      three
# 3      three
# 4          3
#        ...
# 200    three
# 201        2
# 202    three
# 203        1
# 204    three
# Name: Bedrooms, Length: 205, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Area_sqft            205 non-null    object
#  1   Bedrooms             185 non-null    object
#  2   Distance_to_city_km  204 non-null    object
#  3   Age_of_house_yrs     184 non-null    float64
#  4   Has_Garage           205 non-null    object
#  5   Price                195 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 9.7+ KB

# %%
for col in ['Has_Garage']:
    df[col] = df[col].astype(str).str.strip().replace({"nan":np.nan})

# %%
df.Has_Garage
# Out:
# 0      yes
# 1       No
# 2      yes
# 3        N
# 4      Yes
#       ...
# 200      N
# 201    yes
# 202     no
# 203      Y
# 204    Yes
# Name: Has_Garage, Length: 205, dtype: object

# %%
df['Has_Garage'] = df['Has_Garage'].replace({
    'Y': 'Yes', 'y': 'Yes', 'yes': 'Yes', 'YES': 'Yes',
    'N': 'No', 'n': 'No', 'no': 'No', 'NO': 'No'
})

# %%
df.Has_Garage
# Out:
# 0      Yes
# 1       No
# 2      Yes
# 3       No
# 4      Yes
#       ...
# 200     No
# 201    Yes
# 202     No
# 203    Yes
# 204    Yes
# Name: Has_Garage, Length: 205, dtype: object

# %%
for col in ['Has_Garage']:
    df[col] = df[col].replace({"Yes":1,"No":0})
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_15808\410975737.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].replace({"Yes":1,"No":0})

# %%
df.Has_Garage
# Out:
# 0      1.0
# 1      0.0
# 2      1.0
# 3      0.0
# 4      1.0
#       ...
# 200    0.0
# 201    1.0
# 202    0.0
# 203    1.0
# 204    1.0
# Name: Has_Garage, Length: 205, dtype: float64

# %%
df.columns
# Out:
# Index(['Area_sqft', 'Bedrooms', 'Distance_to_city_km', 'Age_of_house_yrs',
#        'Has_Garage', 'Price'],
#       dtype='object')

# %%
df.Bedrooms
# Out:
# 0          4
# 1          4
# 2      three
# 3      three
# 4          3
#        ...
# 200    three
# 201        2
# 202    three
# 203        1
# 204    three
# Name: Bedrooms, Length: 205, dtype: object

# %%
df['Bedrooms'] = df['Bedrooms'].replace({"three":3})
df['Bedrooms'] = pd.to_numeric(df['Bedrooms'],errors='coerce')

# %%
df['Bedrooms']
# Out:
# 0      4.0
# 1      4.0
# 2      3.0
# 3      3.0
# 4      3.0
#       ...
# 200    3.0
# 201    2.0
# 202    3.0
# 203    1.0
# 204    3.0
# Name: Bedrooms, Length: 205, dtype: float64

# %%
df['Bedrooms'].isnull().sum()
# Out:
# np.int64(20)

# %%
df['Bedrooms'] = df['Bedrooms'].apply(lambda x: f"{x:g}")

# %%
df
# Out:
#      Area_sqft Bedrooms Distance_to_city_km  Age_of_house_yrs  Has_Garage  \
# 0         3674        4                15.6               NaN         1.0
# 1    1360 sqft        4                22.4               0.0         0.0
# 2         1794        3                22.4               NaN         1.0
# 3         1630        3                11.2              30.0         0.0
# 4    1595 sqft        3                28.2               0.0         1.0
# ..         ...      ...                 ...               ...         ...
# 200  2646 sqft        3                 9.0              30.0         0.0
# 201       1985        2                 4.0               2.0         1.0
# 202       2257        3                25.6               0.0         0.0
# 203       3314        1                 5.9              15.0         1.0
# 204       3058        3                13.8               5.0         1.0
#
#         Price
# 0    317552.0
# 1    109379.0
# 2     75053.0
# 3    452662.0
# ...

# %%
df['Distance_to_city_km'] = df['Distance_to_city_km'].round().astype(float)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 df['Distance_to_city_km'] = df['Distance_to_city_km'].round().astype(float)
#
# File c:\Users\karan\Desktop\Sleepyy\.spell\Lib\site-packages\pandas\core\series.py:2818, in Series.round(self, decimals, *args, **kwargs)
#    2816 nv.validate_round(args, kwargs)
#    2817 if self.dtype == "object":
# -> 2818     raise TypeError("Expected numeric dtype, got object instead.")
#    2819 new_mgr = self._mgr.round(decimals=decimals, using_cow=using_copy_on_write())
#    2820 return self._constructor_from_mgr(new_mgr, axes=new_mgr.axes).__finalize__(
#    2821     self, method="round"
#    2822 )
#
# TypeError: Expected numeric dtype, got object instead.

# %%
df['Distance_to_city_km']
# Out:
# 0      16.0
# 1      22.0
# 2      22.0
# 3      11.0
# 4      28.0
#        ...
# 200     9.0
# 201     4.0
# 202    26.0
# 203     6.0
# 204    14.0
# Name: Distance_to_city_km, Length: 205, dtype: float64

# %%
print(df['Distance_to_city_km'].unique())
print(df['Distance_to_city_km'].dtype)
# Out:
# [16. 22. 11. 28.  7. 14.  5. nan 21. 18.  9. 26. 12. 25.  3. 10. 30.  4.
#  19. 15. 27.  6. 29. 23.  2. 20. 13.]
# float64

# %%
df['Distance_to_city_km'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Name: Distance_to_city_km, Length: 205, dtype: bool

# %%
df
# Out:
#      Area_sqft Bedrooms  Distance_to_city_km  Age_of_house_yrs  Has_Garage  \
# 1    1360 sqft        4                 22.0               0.0         0.0
# 3         1630        3                 11.0              30.0         0.0
# 4    1595 sqft        3                 28.0               0.0         1.0
# 5         3592        2                  7.0              15.0         1.0
# 7         2669        4                 14.0              15.0         0.0
# ..         ...      ...                  ...               ...         ...
# 200  2646 sqft        3                  9.0              30.0         0.0
# 201       1985        2                  4.0               2.0         1.0
# 202       2257        3                 26.0               0.0         0.0
# 203       3314        1                  6.0              15.0         1.0
# 204       3058        3                 14.0               5.0         1.0
#
#         Price
# 1    109379.0
# 3    452662.0
# 4    706282.0
# ...

# %%
print(df['Distance_to_city_km'].unique())
print(df['Distance_to_city_km'].dtype)
# Out:
# [22. 11. 28.  7. 14.  5. 21. 18.  9. 26. 25.  3. 16. 12. 30. 10.  4.  6.
#  27. 19. 29. 23.  2. 13. 20. 15.]
# float64

# %%
df['Distance_to_city_km'] = df['Distance_to_city_km'].fillna(0)

# %%
df['Distance_to_city_km'].dtype
# Out:
# dtype('O')

# %%
df['Distance_to_city_km'] = pd.to_numeric(df['Distance_to_city_km'], errors='coerce')

# %%
print(df['Distance_to_city_km'].dtype)
# Out:
# float64

# %%
df['Distance_to_city_km'] = pd.to_numeric(df['Distance_to_city_km'], errors='coerce').astype(float)

# %%
df['Distance_to_city_km'] = df['Distance_to_city_km'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 df['Distance_to_city_km'] = df['Distance_to_city_km'].astype(int)
#
# File c:\Users\karan\Desktop\Sleepyy\.spell\Lib\site-packages\pandas\core\generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6664     return res.__finalize__(self, method="astype")
#
# File c:\Users\karan\Desktop\Sleepyy\.spell\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df = df.dropna(subset=['Distance_to_city_km'])
df['Distance_to_city_km'] = df['Distance_to_city_km'].astype(float).astype(int)
# Out:
# C:\Users\karan\AppData\Local\Temp\ipykernel_15808\1017511626.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Distance_to_city_km'] = df['Distance_to_city_km'].astype(float).astype(int)

# %%
print(df['Distance_to_city_km'].unique)
# Out:
# <bound method Series.unique of 0      15.6
# 1      22.4
# 2      22.4
# 3      11.2
# 4      28.2
#        ...
# 200     9.0
# 201     4.0
# 202    25.6
# 203     5.9
# 204    13.8
# Name: Distance_to_city_km, Length: 205, dtype: float64>

# %%
f

# %%
df['Distance_to_city_km']
# Out:
# 0      15.6
# 1      22.4
# 2      22.4
# 3      11.2
# 4      28.2
#        ...
# 200       9
# 201       4
# 202    25.6
# 203     5.9
# 204    13.8
# Name: Distance_to_city_km, Length: 205, dtype: object
